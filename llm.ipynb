# %%
pip install openai PyPDF2
# Out:
# Requirement already satisfied: openai in C:\Users\hp\AppData\Roaming\Python\Python313\site-packages (2.30.0)
# Collecting PyPDF2
#   Downloading pypdf2-3.0.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in C:\Users\hp\AppData\Roaming\Python\Python313\site-packages (from openai) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in C:\Users\hp\AppData\Roaming\Python\Python313\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in C:\Users\hp\AppData\Roaming\Python\Python313\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in C:\Users\hp\AppData\Roaming\Python\Python313\site-packages (from openai) (0.13.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in C:\Users\hp\AppData\Roaming\Python\Python313\site-packages (from openai) (2.12.5)
# Requirement already satisfied: sniffio in C:\Users\hp\AppData\Roaming\Python\Python313\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in C:\Users\hp\AppData\Roaming\Python\Python313\site-packages (from openai) (4.67.3)
# Requirement already satisfied: typing-extensions<5,>=4.11 in C:\Users\hp\AppData\Roaming\Python\Python313\site-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in C:\Users\hp\AppData\Roaming\Python\Python313\site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in C:\Users\hp\AppData\Roaming\Python\Python313\site-packages (from httpx<1,>=0.23.0->openai) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in C:\Users\hp\AppData\Roaming\Python\Python313\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in C:\Users\hp\AppData\Roaming\Python\Python313\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\hp\AppData\Roaming\Python\Python313\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in C:\Users\hp\AppData\Roaming\Python\Python313\site-packages (from pydantic<3,>=1.9.0->openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\hp\AppData\Roaming\Python\Python313\site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Requirement already satisfied: colorama in C:\Users\hp\AppData\Roaming\Python\Python313\site-packages (from tqdm>4->openai) (0.4.6)
# Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-3.0.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from google.colab import files
uploaded = files.upload()
print(uploaded)
file_name = list(uploaded.keys())[0]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from google.colab import files
#       2 uploaded = files.upload()
#       3 print(uploaded)
#
# ModuleNotFoundError: No module named 'google.colab'
